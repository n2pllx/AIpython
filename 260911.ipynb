# %%
import pandas as pd

# %%
print(1+2)
print("2주차")
# Out:
# 3
# 2주차

# %%
a=1
b=2

# %%
print(a+b)
# Out:
# 3

# %%
print(a+b, a-b, a*b, a/b)
# Out:
# 3 -1 2 0.5

# %%
#두 자연수 10와 5가 주어진다.
#이떄, A+B, A-B, A*B, A/B(몫), A%B(나머지)를 출력하는 프로그램을 작설하시오.

A=10
B=5
print(A+B, A-B, A*B, A/B, A%B)
# Out:
# 15 5 50 2.0 0

# %%
#가로 12, 세로 7인 직사각형의 넓이와 둘레를 구하시오.

c=12
d=7
print(c*d, 2*(c+d))
# Out:
# 84 38

# %%
#국어 88,  영어 92, 수학 75점인 학생의 과목 평균을 구하시오.

C=88
D=92
E=75
print((C+D+E)/3)
# Out:
# 85.0
